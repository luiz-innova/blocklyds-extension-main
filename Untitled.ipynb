# %%
import pandas as pd



df = pd.read_csv('https://raw.githubusercontent.com/lcbjrrr/data/main/gender%20-%20tr.csv')

df.head(5)

#<xml xmlns="https://developers.google.com/blockly/xml"><variables><variable id="!}_`cdLoGsx7lTyeKwbZ">df</variable></variables><block type="variables_set" id="NzvEZXCx0OW[yUZ5YDbS" x="-10" y="-6"><field name="VAR" id="!}_`cdLoGsx7lTyeKwbZ">df</field><value name="VALUE"><block type="read_csv" id="GnP!VL~eW_nK|O$}WI/0"><value name="read"><block type="text" id="9UK8V?utKtc?`s}*hTo~"><field name="TEXT">https://raw.githubusercontent.com/lcbjrrr/data/main/gender%20-%20tr.csv</field></block></value></block></value></block><block type="headTail" id="yqEdT$h6a)8U^Rey.|-%" x="-7" y="65"><field name="FIELDNAME">head</field><value name="dataframe"><block type="variables_get" id="7)hJ63JVXKq5;a2(1fm*"><field name="VAR" id="!}_`cdLoGsx7lTyeKwbZ">df</field></block></value></block></xml>
# Out:
#    G    H   W
# 0  0  178  72
# 1  0  179  81
# 2  1  163  55
# 3  1  168  58
# 4  0  181  98

# %%
from sklearn.cluster import KMeans
import seaborn as sns



k = KMeans(n_clusters=2).fit(df[["H","W"]]).labels_
print(k)

sns.scatterplot(x = df["H"], y = df["W"]).set(**{})

#<xml xmlns="https://developers.google.com/blockly/xml"><variables><variable id="eslJW/or5Qw4t/cl:]B}">k</variable><variable id="!}_`cdLoGsx7lTyeKwbZ">df</variable></variables><block type="variables_set" id="#)eN1%.Qw;M:XaY|K}yl" x="-36" y="141"><field name="VAR" id="eslJW/or5Qw4t/cl:]B}">k</field><value name="VALUE"><block type="kmeans" id="{%U/Zdl{8s~dJY(_y_6`"><value name="k"><block type="math_number" id="lO_4[j*P[H*=Ym$tv+go"><field name="NUM">2</field></block></value><value name="features"><block type="select" id="}Lx5AI,*Qkf~c6grFyd9"><mutation xmlns="http://www.w3.org/1999/xhtml" items="2"></mutation><value name="select"><block type="variables_get" id="7aTM1Azha,]^*PR[6VrT"><field name="VAR" id="!}_`cdLoGsx7lTyeKwbZ">df</field></block></value><value name="ADD0"><block type="text" id="qX}w|]mw;,%dat.1358Z"><field name="TEXT">H</field></block></value><value name="ADD1"><block type="text" id="7dzkA.[q0g6FrCK3G%)7"><field name="TEXT">W</field></block></value></block></value></block></value><next><block type="text_print" id="[h^v[zL:S:9WJI0yU!-R"><value name="TEXT"><shadow type="text" id="zB[hX5Aje.!zrH*i,Q=x"><field name="TEXT">abc</field></shadow><block type="variables_get" id="BU!Ah{5?CMnCd@g{b|,t"><field name="VAR" id="eslJW/or5Qw4t/cl:]B}">k</field></block></value></block></next></block><block type="scatterGraph" id="F?4.T],~w~pSd??)7o.L" x="-49" y="319"><value name="x"><block type="select" id="/Uo;,y!U@cQ15.DHIq7;"><mutation xmlns="http://www.w3.org/1999/xhtml" items="1"></mutation><value name="select"><block type="variables_get" id="+`p}gPYe~W,F-+yf6_Fy"><field name="VAR" id="!}_`cdLoGsx7lTyeKwbZ">df</field></block></value><value name="ADD0"><block type="text" id=",z.xjzK0x@9j,@.tFTLP"><field name="TEXT">H</field></block></value></block></value><value name="y"><block type="select" id="A;lECewD`v.Sim_*WP!_"><mutation xmlns="http://www.w3.org/1999/xhtml" items="1"></mutation><value name="select"><block type="variables_get" id="Wh[0q@o_M4eqYcPh=t40"><field name="VAR" id="!}_`cdLoGsx7lTyeKwbZ">df</field></block></value><value name="ADD0"><block type="text" id="h5cX4!4A-wH]zMMDedL["><field name="TEXT">W</field></block></value></block></value></block></xml>
# Out:
# [0 1 0 0 1 0 1 0]
# C:\Users\vitor\miniforge\envs\blocklyds-latest\Lib\site-packages\sklearn\cluster\_kmeans.py:1411: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# []
